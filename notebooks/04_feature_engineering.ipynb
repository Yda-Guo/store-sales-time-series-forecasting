# %% [markdown]
# # Horizon-Aware Feature Engineering
#
# Each row is `forecast_origin x store x family x horizon`, with horizons 1-16 pooled in one model.

# %%
from pathlib import Path
ROOT = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
ROOT

# %% [markdown]
# Run `python -m src.features` and `python -m unittest discover -s tests -v`. The same constructor serves historical origins, development folds, final holdout, and Kaggle inference. See [`reports/feature_engineering.md`](../reports/feature_engineering.md).
