# %% [markdown]
# # Exploratory Data Analysis
#
# Run `python -m src.audit_data` and `python -m src.eda` from the repository root to regenerate the audit, compact figures, and narrative.

# %%
from pathlib import Path
ROOT = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
ROOT

# %% [markdown]
# The saved analysis describes scale, weekly pattern, product-family heterogeneity, and promotion association without causal claims. See [`reports/eda_summary.md`](../reports/eda_summary.md).
